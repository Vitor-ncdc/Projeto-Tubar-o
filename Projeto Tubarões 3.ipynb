# %% [markdown]
# # Projeto Tubarões

# %%
#Regiao
#Fatalidade
#Data

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('attacks.csv', sep=',', index_col = 1, encoding='latin-1')

# %%
# visualizando cabeçalho

df.head()
# Out:
#             Case Number    Year        Type    Country             Area  \
# Date
# 25-Jun-2018  2018.06.25  2018.0     Boating        USA       California
# 18-Jun-2018  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 09-Jun-2018  2018.06.09  2018.0     Invalid        USA           Hawaii
# 08-Jun-2018  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 04-Jun-2018  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                                    Location     Activity             Name  \
# Date
# 25-Jun-2018     Oceanside, San Diego County     Paddling      Julie Wolfe
# 18-Jun-2018  St. Simon Island, Glynn County     Standing  Adyson McNeely
# 09-Jun-2018                    Habush, Oahu      Surfing      John Denges
# 08-Jun-2018              Arrawarra Headland      Surfing             male
# 04-Jun-2018                        La Ticla  Free diving   Gustavo Ramos
#
# ...

# %%
df
# Out:
#             Case Number    Year        Type    Country             Area  \
# Date
# 25-Jun-2018  2018.06.25  2018.0     Boating        USA       California
# 18-Jun-2018  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 09-Jun-2018  2018.06.09  2018.0     Invalid        USA           Hawaii
# 08-Jun-2018  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 04-Jun-2018  2018.06.04  2018.0    Provoked     MEXICO           Colima
# ...                 ...     ...         ...        ...              ...
# NaN                 NaN     NaN         NaN        NaN              NaN
# NaN                 NaN     NaN         NaN        NaN              NaN
# NaN                 NaN     NaN         NaN        NaN              NaN
# NaN                 NaN     NaN         NaN        NaN              NaN
# NaN                  xx     NaN         NaN        NaN              NaN
#
#                                    Location     Activity             Name  \
# Date
# ...

# %%
# Contabilizando os dados de uma coluna

df['Fatal (Y/N)'].value_counts()
# Out:
# N          4293
# Y          1388
# UNKNOWN      71
#  N            7
# M             1
# 2017          1
# N             1
# y             1
# Name: Fatal (Y/N), dtype: int64

# %%
df.columns
# Out:
# Index(['Case Number', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
print(df.duplicated())
# Out:
# Date
# 25-Jun-2018    False
# 18-Jun-2018    False
# 09-Jun-2018    False
# 08-Jun-2018    False
# 04-Jun-2018    False
#                ...
# NaN             True
# NaN             True
# NaN             True
# NaN             True
# NaN            False
# Length: 25723, dtype: bool

# %%
df2 = df[['Year','Country','Fatal (Y/N)']]

# %%
df2
# Out:
#                Year    Country Fatal (Y/N)
# Date
# 25-Jun-2018  2018.0        USA           N
# 18-Jun-2018  2018.0        USA           N
# 09-Jun-2018  2018.0        USA           N
# 08-Jun-2018  2018.0  AUSTRALIA           N
# 04-Jun-2018  2018.0     MEXICO           N
# ...             ...        ...         ...
# NaN             NaN        NaN         NaN
# NaN             NaN        NaN         NaN
# NaN             NaN        NaN         NaN
# NaN             NaN        NaN         NaN
# NaN             NaN        NaN         NaN
#
# [25723 rows x 3 columns]

# %%
df2.dropna(how='all', inplace=True)

# %%
df2
# Out:
#                Year             Country Fatal (Y/N)
# Date
# 25-Jun-2018  2018.0                 USA           N
# 18-Jun-2018  2018.0                 USA           N
# 09-Jun-2018  2018.0                 USA           N
# 08-Jun-2018  2018.0           AUSTRALIA           N
# 04-Jun-2018  2018.0              MEXICO           N
# ...             ...                 ...         ...
# Before 1903     0.0           AUSTRALIA           Y
# Before 1903     0.0           AUSTRALIA           Y
# 1900-1905       0.0                 USA           Y
# 1883-1889       0.0              PANAMA           Y
# 1845-1853       0.0  CEYLON (SRI LANKA)           Y
#
# [6302 rows x 3 columns]

# %%
#apagar todas as vazias

df2.dropna(how='any')
# Out:
#                Year             Country Fatal (Y/N)
# Date
# 25-Jun-2018  2018.0                 USA           N
# 18-Jun-2018  2018.0                 USA           N
# 09-Jun-2018  2018.0                 USA           N
# 08-Jun-2018  2018.0           AUSTRALIA           N
# 04-Jun-2018  2018.0              MEXICO           N
# ...             ...                 ...         ...
# Before 1903     0.0           AUSTRALIA           Y
# Before 1903     0.0           AUSTRALIA           Y
# 1900-1905       0.0                 USA           Y
# 1883-1889       0.0              PANAMA           Y
# 1845-1853       0.0  CEYLON (SRI LANKA)           Y
#
# [5717 rows x 3 columns]

# %%
df2.set_index(['Fatal (Y/N)'])
# Out:
#                Year             Country
# Fatal (Y/N)
# N            2018.0                 USA
# N            2018.0                 USA
# N            2018.0                 USA
# N            2018.0           AUSTRALIA
# N            2018.0              MEXICO
# ...             ...                 ...
# Y               0.0           AUSTRALIA
# Y               0.0           AUSTRALIA
# Y               0.0                 USA
# Y               0.0              PANAMA
# Y               0.0  CEYLON (SRI LANKA)
#
# [6302 rows x 2 columns]

# %%
# Selecionando informações maiores que 2015

df3 = df2.loc[df2['Year'] > 2015]

# %%
df3
# Out:
#                         Year               Country Fatal (Y/N)
# Date
# 25-Jun-2018           2018.0                   USA           N
# 18-Jun-2018           2018.0                   USA           N
# 09-Jun-2018           2018.0                   USA           N
# 08-Jun-2018           2018.0             AUSTRALIA           N
# 04-Jun-2018           2018.0                MEXICO           N
# ...                      ...                   ...         ...
# 24-Jan-2016           2016.0  UNITED ARAB EMIRATES           N
# 23-Jan-2016           2016.0                   USA           N
# Reported 11-Jan-2016  2016.0             AUSTRALIA           N
# 05-Jan-2016           2016.0             AUSTRALIA           N
# 02-Jan-2016           2016.0             AUSTRALIA           N
#
# [319 rows x 3 columns]

# %%
df3.groupby(['Year','Country']).sum().head(60)
# Out:
#                                                                                     Fatal (Y/N)
# Year   Country
# 2016.0 AUSTRALIA                                                 NNNNNNNNNNNNNNNNNNNYYNNNNNNNNN
#        BAHAMAS                                                                             NNNN
#        BRAZIL                                                                                NN
#        CAPE VERDE                                                                             0
#        CAYMAN ISLANDS                                                                         0
#        CHINA                                                                                  N
#        COLUMBIA                                                                               N
#        DOMINICAN REPUBLIC                                                                     N
#        EGYPT                                                                                  N
# ...

# %%
df4 = df3.groupby(['Year','Country'])['Fatal (Y/N)'].count()

# %%
df3.columns
# Out:
# Index(['Year', 'Country', 'Fatal (Y/N)'], dtype='object')

# %%
df3['Fatal (Y/N)'].unique()
# Out:
# array(['N', 'Y', nan, 'M'], dtype=object)

# %%
df3['Year'].unique()
# Out:
# array([2018., 2017., 2016.])

# %%
df3['Country'].unique()
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'ENGLAND', 'SOUTH AFRICA',
#        'THAILAND', 'COSTA RICA', 'MALDIVES', 'BAHAMAS', 'NEW CALEDONIA',
#        'ECUADOR', 'MALAYSIA', 'LIBYA', nan, 'CUBA', 'MAURITIUS',
#        'NEW ZEALAND', 'SPAIN', 'SAMOA', 'SOLOMON ISLANDS', 'JAPAN',
#        'EGYPT', 'ST HELENA, British overseas territory', 'COMOROS',
#        'REUNION', 'FRENCH POLYNESIA', 'UNITED KINGDOM',
#        'UNITED ARAB EMIRATES', 'PHILIPPINES', 'INDONESIA', 'CHINA',
#        'COLUMBIA', 'CAPE VERDE', 'Fiji', 'DOMINICAN REPUBLIC',
#        'CAYMAN ISLANDS'], dtype=object)

# %%
df6 = df3[['Fatal (Y/N)']]

# %%
df6.count('Country')
# Out:
# Fatal (Y/N)    294
# dtype: int64

# %%
df3['Fatal (Y/N)'].value_counts()
# Out:
# N    279
# Y     14
# M      1
# Name: Fatal (Y/N), dtype: int64

# %%
df3.groupby(['Country'])[['Fatal (Y/N)']].count()
# Out:
#                                        Fatal (Y/N)
# Country
# AUSTRALIA                                       75
# BAHAMAS                                         14
# BRAZIL                                           8
# CAPE VERDE                                       0
# CAYMAN ISLANDS                                   0
# CHINA                                            1
# COLUMBIA                                         1
# COMOROS                                          0
# COSTA RICA                                       3
# CUBA                                             1
# DOMINICAN REPUBLIC                               1
# ECUADOR                                          1
# EGYPT                                            2
# ENGLAND                                          1
# FRENCH POLYNESIA                                 4
# Fiji                                             1
# INDONESIA                                        2
# ...

# %%
ft = df3[df3['Fatal (Y/N)'] == 'Y']

# %%
ft.groupby(['Country'])[['Fatal (Y/N)']].count()
# Out:
#                Fatal (Y/N)
# Country
# AUSTRALIA                3
# BRAZIL                   1
# COSTA RICA               1
# CUBA                     1
# Fiji                     1
# LIBYA                    1
# MEXICO                   1
# NEW CALEDONIA            2
# REUNION                  2
# SOUTH AFRICA             1
